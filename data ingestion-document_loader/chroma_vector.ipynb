# %%
from langchain_chroma import Chroma
from langchain_community.document_loaders import TextLoader
from langchain_community.embeddings import OllamaEmbeddings
from langchain_text_splitters import RecursiveCharacterTextSplitter

# %%
loader = TextLoader('sample.txt')
documents = loader.load()
documents
# Out:
# [Document(metadata={'source': 'sample.txt'}, page_content='‘Good morning Principal Sir, teachers, and my dear friends. Today, I stand before you to present my speech about life. We all want a successful life so that we can live a happy and material life. But, what is the meaning of life? Is life only about happiness, joy, and materialistic things?’\n\n‘Happiness and material needs are our desires offered by life as a reward for our hard work and luck. Life is a challenging journey. Sometimes there are clouds of darkness, lost in shadows. However, even in times like these, life teaches us to discover our inner strength, resilience, and the capacity to emerge into the light with newfound wisdom and growth.’\n\nEverybody has a purpose in their lives and to fulfill them, we have to fight our own battles. We have to study hard to succeed in exams, practice deliberately to win a competition, etc. Life is challenging, but that is what makes life so special. \n\nEdmund Hillary and Tibetan mountaineer Tenzing Norgay, the first persons to climb the highest mountain peak, Mount Everest, failed 6 times. He, along with Edmund Hillary, finally climbed to the top of the Everest in their 7th attempt. They knew about the challenges and difficulties that would come with their mission, but they still did the impossible.')]

# %%
text_splitter = RecursiveCharacterTextSplitter(chunk_size=100, chunk_overlap=0)
texts = text_splitter.split_documents(documents)
texts
# Out:
# [Document(metadata={'source': 'sample.txt'}, page_content='‘Good morning Principal Sir, teachers, and my dear friends. Today, I stand before you to present my'),
#  Document(metadata={'source': 'sample.txt'}, page_content='speech about life. We all want a successful life so that we can live a happy and material life.'),
#  Document(metadata={'source': 'sample.txt'}, page_content='But, what is the meaning of life? Is life only about happiness, joy, and materialistic things?’'),
#  Document(metadata={'source': 'sample.txt'}, page_content='‘Happiness and material needs are our desires offered by life as a reward for our hard work and'),
#  Document(metadata={'source': 'sample.txt'}, page_content='luck. Life is a challenging journey. Sometimes there are clouds of darkness, lost in shadows.'),
#  Document(metadata={'source': 'sample.txt'}, page_content='However, even in times like these, life teaches us to discover our inner strength, resilience, and'),
#  Document(metadata={'source': 'sample.txt'}, page_content='the capacity to emerge into the light with newfound wisdom and growth.’'),
#  Document(metadata={'source': 'sample.txt'}, page_content='Everybody has a purpose in their lives and to fulfill them, we have to fight our own battles. We'),
#  Document(metadata={'source': 'sample.txt'}, page_content='have to study hard to succeed in exams, practice deliberately to win a competition, etc. Life is'),
#  Document(metadata={'source': 'sample.txt'}, page_content='challenging, but that is what makes life so special.'),
#  Document(metadata={'source': 'sample.txt'}, page_content='Edmund Hillary and Tibetan mountaineer Tenzing Norgay, the first persons to climb the highest'),
#  Document(metadata={'source': 'sample.txt'}, page_content='mountain peak, Mount Everest, failed 6 times. He, along with Edmund Hillary, finally climbed to the'),
#  Document(metadata={'source': 'sample.txt'}, page_content='top of the Everest in their 7th attempt. They knew about the challenges and difficulties that would'),
#  Document(metadata={'source': 'sample.txt'}, page_content='come with their mission, but they still did the impossible.')]

# %%
embedding = OllamaEmbeddings()
vectordb = Chroma.from_documents(documents=texts,embedding=embedding)

# %%
vectordb

# %%
query = "What is RAG?"
docs = vectordb.similarity_search(query)    
docs[0].page_content
# Out:
# 'mountain peak, Mount Everest, failed 6 times. He, along with Edmund Hillary, finally climbed to the'

# %%
## save to  local disk

vectordb = Chroma.from_documents(documents=texts, embedding=embedding, persist_directory="./chroma_db")
